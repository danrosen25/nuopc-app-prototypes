# %% [markdown]
# <span class="ͼ12">
# <center><h1>All NUOPC Tutorials</h1></center>
# </span>
#
# <span class="ͼ16">
# <h2>Standard Tutorials</h2>
# </span>
#
# - (none)
#
# <span class="ͼ16">
# <h2>ESMX Tutorials</h2>
# </span>
#
# - [ESMX StartHere Tutorial](ESMX_StartHereProto/ESMX_StartHereTutorial.ipynb) <button data-commandLinker-command="filebrowser:go-to-path" data-commandlinker-args='{"path": "ESMX_StartHereProto"}'>Go to Folder</button>
#
# <span class="ͼ16">
# <h2>Component Tutorials</h2>
# </span>
#
# - [Community Fire Behavior Model Tutorial](Tutorials/ESMX_CFBMTutorial.ipynb) <button data-commandLinker-command="filebrowser:go-to-path" data-commandlinker-args='{"path": "Tutorials"}'>Go to Folder</button>
